# %% [markdown]
# <a href="https://colab.research.google.com/github/agner34/pynthon/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula 1**  ✅  :  ✌![Nossa Senhora Aparecida - Padroeira do Brasil.jpeg](data:image/jpeg;base64,...)

# %%
ano = "IX"
print(ano, " competição de programação dá Start")
# Out:
# IX  competição de programação dá Start

# %% [markdown]
# # **aula 2**  ✅  ❣  ⚾

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5 * livro_infantil
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais de ana são {pontos_ana}")
print(f"Os pontos totais sao {pontos_ana + pontos_rodrigo} ")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais de ana são 46
# Os pontos totais sao 70

# %% [markdown]
# aula 3 🫠😐🤫

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))

print(f"João recebeu {figurinhas_joao} figurinhas")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2782903720.py in <cell line: 0>()
# ----> 1 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
#       2 numero_de_amigos = int(input("Digite o número de amigos: "))
#       3
#       4 print(f"João recebeu {figurinhas_joao} figurinhas")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# aula 4 😶‍🌫️🤤🤨

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %% [markdown]
# aula 5  😟😣😰

# %%
def divisao(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} / {contador} = {numero // contador}")
numero = int(input("Digite um número para ver sua divisão: "))
divisao(numero)
# Out:
# Digite um número para ver sua divisão: 4
# 4 / 1 = 4
# 4 / 2 = 2
# 4 / 3 = 1
# 4 / 4 = 1
# 4 / 5 = 0
# 4 / 6 = 0
# 4 / 7 = 0
# 4 / 8 = 0
# 4 / 9 = 0
# 4 / 10 = 0

# %% [markdown]
# aula 6  👻🙁☠️

# %%
print("Olá, sou seu assistente virtual, em que posso ajudar?")
nome = input("Digite seu nome: ")
resposta = input(f"Olá {nome}, qual tema você deseja conversar? Python, Javascript ou Matemática ").lower()
if resposta == "python":
  print (f"Ótimo {nome}, vamos falar sobre Python. \n Python é uma das linguagens de programação mais populares e versáteis do mundo. Ela foi criada por Guido van Rossum no final dos anos 1980 e lançada oficialmente em 1991. Desde então, Python se destacou por ser simples, legível e poderosa, o que a torna ideal tanto para iniciantes quanto para programadores experientes.")
elif resposta == "javascript":
  print (f"Ótimo {nome}, vamos falar sobre Javascript. \n O JavaScript (JS) é uma das linguagens de programação mais importantes do mundo, especialmente para quem quer trabalhar com desenvolvimento web. Ele é o que dá vida e interatividade às páginas da internet — enquanto o HTML estrutura o conteúdo e o CSS define o visual, o JavaScript faz tudo “funcionar”. ")
elif resposta == "matemática":
  print (f"Ótimo {nome}, vamos falar sobre matematica. \n A matemática é a ciência dos números, formas, quantidades e padrões. Ela busca compreender e descrever o mundo através de símbolos, fórmulas e raciocínio lógico.")
else:
  print(f"Que pena {nome} que, não sei falar sobre esse assunto.")
# Out:
# Olá, sou seu assistente virtual, em que posso ajudar?
# Digite seu nome: aggngn
# Olá aggngn, qual tema você deseja conversar? Python, Javascript ou Matemática python
# Ótimo aggngn, vamos falar sobre Python.
#  Python é uma das linguagens de programação mais populares e versáteis do mundo. Ela foi criada por Guido van Rossum no final dos anos 1980 e lançada oficialmente em 1991. Desde então, Python se destacou por ser simples, legível e poderosa, o que a torna ideal tanto para iniciantes quanto para programadores experientes.

# %% [markdown]
# aula 6 - listas  📋😵‍💫🙄

# %%
import random
dica = [
    "Não espere pela oportunidade perfeita. A perfeição está em criar a sua própria oportunidade todos os dias 😉",
    "Acredite no seu potencial, mesmo quando ninguém mais acreditar. O primeiro passo para o sucesso é confiar em si mesmo 😶‍🌫️",
    "O segredo da felicidade não está no destino, mas na jornada. Aproveite cada passo, por menor que seja 🌱😊",
    "Não se compare com os outros. A sua única competição é a pessoa que você foi ontem 🏁👤",
    "A verdadeira mudança começa de dentro. Cultive a paz e o equilíbrio dentro de si e o mundo ao seu redor começará a refletir isso 🕊️💖",
    "Não se deixe paralisar pelo medo do fracasso. O erro é apenas uma lição disfarçada de oportunidade 🔄🔥",
    "O melhor investimento que você pode fazer é em si mesmo. Cuide da sua mente, corpo e alma, e o resto virá como consequência 🌱💫",
    ]
while True:
  pedido = input ("digite 'dica' para receber uma dica ou 'sair' para encerrar \n ") .lower ()

  if pedido == "dica":
    dica = random.choice(dica) # escolhe uma dica aleatória sair
    print(f"Dica: {dica} \n")
    break
  elif pedido == "sair":
    print("Até a próxima! \n")
    break
# Out:
# digite 'dica' para receber uma dica ou 'sair' para encerrar
#  dica
# Dica: Não se compare com os outros. A sua única competição é a pessoa que você foi ontem 🏁👤
